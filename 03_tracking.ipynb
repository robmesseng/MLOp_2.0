# %% [markdown]
# Intentaremos hacer distintas formas de tracking del modelo

# %%
import pandas as pd

# %%
logs = pd.read_csv('logs/003/version_0/metrics.csv')
logs
# Out:
#     val_acc  val_loss  step  epoch      loss   acc
# 0   0.91250  0.277841    25      0       NaN   NaN
# 1       NaN       NaN    49      1  0.081738  1.00
# 2   0.93125  0.215774    51      1       NaN   NaN
# 3   0.94375  0.204151    77      2       NaN   NaN
# 4       NaN       NaN    99      3  0.383577  0.84
# 5   0.91250  0.205694   103      3       NaN   NaN
# 6   0.90000  0.231183   129      4       NaN   NaN
# 7       NaN       NaN   149      5  0.026058  1.00
# 8   0.89375  0.252739   155      5       NaN   NaN
# 9   0.95000  0.188284   181      6       NaN   NaN
# 10      NaN       NaN   199      7  0.080490  1.00
# 11  0.90000  0.212954   207      7       NaN   NaN
# 12  0.94375  0.184810   233      8       NaN   NaN
# 13      NaN       NaN   249      9  0.091665  0.96
# 14  0.89375  0.257874   259      9       NaN   NaN

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(6, 3))
ax = plt.subplot(1,2,1)
logs['val_loss'].dropna().plot(ax=ax)
logs['loss'].dropna().plot(ax=ax)
ax.legend(['val_loss', 'loss'])
ax.grid(True)
ax = plt.subplot(1,2,2)
logs['val_acc'].dropna().plot(ax=ax)
logs['acc'].dropna().plot(ax=ax)
ax.legend(['val_acc', 'acc'])
ax.grid(True)
plt.tight_layout()
plt.show()
